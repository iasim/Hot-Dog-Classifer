# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import h5py 
import scipy
import imageio
from PIL import Image

from google.colab import drive
drive.mount('/content/gdrive')

root_path = '/content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets'



# config - change these to run the code natively

test_hot_dogs_dir = root_path+"/test/hot_dog"
test_not_hot_dogs_dir = root_path+"/test/not_hot_dog"

train_hot_dogs_dir = root_path+"/train/hot_dog" 
train_not_hot_dogs_dir = root_path+"/train/not_hot_dog"

dimention = 64         #convert any img to 64x64 img in preprocessing


#returns train_set_x_orig, train_set_y_orig, test_set_x_orig, test_set_y_orig, classes
def load_dataset_native():
    
    #1. convert Image dirs to numpy arrays 4x
        #1. call preProcess on each image then add image to array
    
    print("Loading the datasets to numpy arrays")
    test_hd_arr = imageDirToNumpyArr(test_hot_dogs_dir, dimention)          #1 res
    test_nhd_arr = imageDirToNumpyArr(test_not_hot_dogs_dir,dimention)      #0 res
    
    train_hd_arr = imageDirToNumpyArr(train_hot_dogs_dir, dimention)        #1 res
    train_nhd_arr = imageDirToNumpyArr(train_not_hot_dogs_dir, dimention)   #0 res
    

    #2. flatten the array, add the result
    print("Flattening the images to [64*64*3 x 1] dimentions")
    flat_test_hd = flattenAndAddResult(test_hd_arr,1)
    flat_test_nhd = flattenAndAddResult(test_nhd_arr,0)
    flat_train_hd = flattenAndAddResult(train_hd_arr,1)
    flat_train_nhd = flattenAndAddResult(train_nhd_arr,0)
    
    
    #2. Merge the two types of testing, and two types of training data to 2 classes, then mix
    
    flat_test = mergeAndMixArrays(flat_test_hd, flat_test_nhd)
    flat_train = mergeAndMixArrays(flat_train_hd, flat_train_nhd)
        
    #3. Separate the y (last column from train and test)
    yTest = flat_test[-1]
    yTrain = flat_train[-1]
    
    #delete the last row as its saved in the y
    #np.delete(flat_test, -1, 0)
    #np.delete(flat_train, -1, 0)
    
    return flat_train[:-1], yTrain, flat_test[:-1], yTest

#returns a numpy array from the directory address for an image directory
def imageDirToNumpyArr(im_dir_path, zero_or_one):
    arr = os.listdir(im_dir_path)
    result_arr = np.empty([len(arr), dimention, dimention, 3], dtype='int16');
    
    # preprocess each image
    for i in range(0,len(arr)):
        f_path = im_dir_path + '/' +arr[i]
        im_array=preprocess(f_path, dimention)
        result_arr[i]= im_array
    
    return result_arr
    

def preprocess(image_path, num_px):
    print()
    print("Preprocessing Image: ", image_path)
    image = Image.open(image_path)
    print("Image Size: ",image.size)
    print()
    
    resized_image = image.resize((num_px,num_px))
    print("Image Size: ",resized_image.size)
    image_arr = np.array(resized_image)
    return image_arr

    
def flattenAndAddResult(arr, res_zero_or_one):
    # Flatten
    flat = arr.reshape(arr.shape[0], -1).T
    # Add the result ->?
    
    print ("arr shape: " + str(flat.shape))
    
    # standardize
    flat=flat/255       # divide every row of the dataset by 255 (the maximum value of a pixel channel)
    
    # Add a row of res_zero_or_one
    if(res_zero_or_one == 1):
        newRow = np.ones((1, flat.shape[1]),dtype=int)
        res = np.vstack((flat,newRow))
        
    else:
        newRow = np.zeros((1, flat.shape[1]),dtype=int)
        res = np.vstack((flat,newRow))
            
    return res

    

# merge teain test subarrays, mix them afterwordss
def mergeAndMixArrays(flat_arr1, flat_arr2):
    print("Merging, mixing data")
    
    # merge
    res = np.column_stack((flat_arr1, flat_arr2))
    
    # mix and return
    np.random.shuffle(np.transpose(res))
    return res
    

    
def sigmoid(z):
    """
    Compute the sigmoid of z

    Arguments:
    z -- A scalar or numpy array of any size.

    Return:
    s -- sigmoid(z)
    """

    s = 1/(1 + np.exp(-z))
    
    return s



# GRADED FUNCTION: initialize_with_zeros
def initialize_with_zeros(dim):
    """
    This function creates a vector of zeros of shape (dim, 1) for w and initializes b to 0.
    
    Argument:
    dim -- size of the w vector we want (or number of parameters in this case)
    
    Returns:
    w -- initialized vector of shape (dim, 1)
    b -- initialized scalar (corresponds to the bias)
    """
    
    w = np.zeros((dim,1))
    b = 0
    assert(w.shape == (dim, 1))
    assert(isinstance(b, float) or isinstance(b, int))
    
    return w, b



def propagate(w, b, X, Y):
    """
    Implement the cost function and its gradient for the propagation explained above

    Arguments:
    w -- weights, a numpy array of size (num_px * num_px * 3, 1)
    b -- bias, a scalar
    X -- data of size (num_px * num_px * 3, number of examples)
    Y -- true "label" vector (containing 0 if non-cat, 1 if cat) of size (1, number of examples)

    Return:
    cost -- negative log-likelihood cost for logistic regression
    dw -- gradient of the loss with respect to w, thus same shape as w
    db -- gradient of the loss with respect to b, thus same shape as b
    
    Tips:
    - Write your code step by step for the propagation. np.log(), np.dot()
    """
    
    m = X.shape[1]
    
    # FORWARD PROPAGATION (FROM X TO COST)
    A = sigmoid(np.dot(w.T, X)+b)                                                               # compute activation
    cost = np.sum(Y * np.log(A) + (1 - Y) * np.log(1 - A))* 1 / (- m)                     # compute cost
    
    # BACKWARD PROPAGATION (TO FIND GRAD)
    dw = np.dot(X,(A-Y).T) * 1 / ( m)
    db = np.sum(A-Y) * 1 / ( m)

    assert(dw.shape == w.shape)
    assert(db.dtype == float)
    cost = np.squeeze(cost)
    assert(cost.shape == ())
    
    grads = {"dw": dw,
             "db": db}
    
    return grads, cost


epsilon = 1e-5    



# GRADED FUNCTION: optimize
def optimize(w, b, X, Y, num_iterations, learning_rate, print_cost = False):
    """
    This function optimizes w and b by running a gradient descent algorithm
    
    Arguments:
    w -- weights, a numpy array of size (num_px * num_px * 3, 1)
    b -- bias, a scalar
    X -- data of shape (num_px * num_px * 3, number of examples)
    Y -- true "label" vector (containing 0 if non-cat, 1 if cat), of shape (1, number of examples)
    num_iterations -- number of iterations of the optimization loop
    learning_rate -- learning rate of the gradient descent update rule
    print_cost -- True to print the loss every 100 steps
    
    Returns:
    params -- dictionary containing the weights w and bias b
    grads -- dictionary containing the gradients of the weights and bias with respect to the cost function
    costs -- list of all the costs computed during the optimization, this will be used to plot the learning curve.
    
    Tips:
    You basically need to write down two steps and iterate through them:
        1) Calculate the cost and the gradient for the current parameters. Use propagate().
        2) Update the parameters using gradient descent rule for w and b.
    """
    
    costs = []
    
    for i in range(num_iterations):
        
        
        # Cost and gradient calculation (≈ 1-4 lines of code)
        grads, cost = propagate(w,b,X,Y)
        
        # Retrieve derivatives from grads
        dw = grads["dw"]
        db = grads["db"]
        
        # update rule (≈ 2 lines of code)
        w = w-learning_rate*dw
        b = b-learning_rate*db
        
        # Record the costs
        if i % 100 == 0:
            costs.append(cost)
        
        # Print the cost every 100 training iterations
        if print_cost and i % 100 == 0:
            print ("Cost after iteration %i: %f" %(i, cost))
    
    params = {"w": w,
              "b": b}
    
    grads = {"dw": dw,
             "db": db}
    
    return params, grads, costs


# GRADED FUNCTION: predict
def predict(w, b, X):
    '''
    Predict whether the label is 0 or 1 using learned logistic regression parameters (w, b)
    
    Arguments:
    w -- weights, a numpy array of size (num_px * num_px * 3, 1)
    b -- bias, a scalar
    X -- data of size (num_px * num_px * 3, number of examples)
    
    Returns:
    Y_prediction -- a numpy array (vector) containing all predictions (0/1) for the examples in X
    '''
    
    m = X.shape[1]
    Y_prediction = np.zeros((1,m))
    w = w.reshape(X.shape[0], 1)
    
    # Compute vector "A" predicting the probabilities of a cat being present in the picture
    A = sigmoid(np.dot(w.T,X)+b)
    
    for i in range(A.shape[1]):
        
        # Convert probabilities A[0,i] to actual predictions p[0,i]
        Y_prediction[0,i]=1 if A[0,i]>0.5 else 0
    
    assert(Y_prediction.shape == (1, m))
    
    return Y_prediction


# GRADED FUNCTION: model
def model(X_train, Y_train, X_test, Y_test, num_iterations = 2000, learning_rate = 0.5, print_cost = False):
    """
    Builds the logistic regression model by calling the function you've implemented previously
    
    Arguments:
    X_train -- training set represented by a numpy array of shape (num_px * num_px * 3, m_train)
    Y_train -- training labels represented by a numpy array (vector) of shape (1, m_train)
    X_test -- test set represented by a numpy array of shape (num_px * num_px * 3, m_test)
    Y_test -- test labels represented by a numpy array (vector) of shape (1, m_test)
    num_iterations -- hyperparameter representing the number of iterations to optimize the parameters
    learning_rate -- hyperparameter representing the learning rate used in the update rule of optimize()
    print_cost -- Set to true to print the cost every 100 iterations
    
    Returns:
    d -- dictionary containing information about the model.
    """
    
    
    # initialize parameters with zeros (≈ 1 line of code)
    w, b = initialize_with_zeros(X_train.shape[0])

    # Gradient descent (≈ 1 line of code)
    parameters, grads, costs = optimize(w, b, X_train, Y_train, num_iterations, learning_rate, False)
    
    # Retrieve parameters w and b from dictionary "parameters"
    w = parameters["w"]
    b = parameters["b"]
    
    # Predict test/train set examples (≈ 2 lines of code)
    Y_prediction_train = predict(w, b, X_train)
    Y_prediction_test = predict(w, b, X_test)


    # Print train/test Errors
    print("train accuracy: {} %".format(100 - np.mean(np.abs(Y_prediction_train - Y_train)) * 100))
    print("test accuracy: {} %".format(100 - np.mean(np.abs(Y_prediction_test - Y_test)) * 100))

    
    d = {"costs": costs,
         "Y_prediction_test": Y_prediction_test, 
         "Y_prediction_train" : Y_prediction_train, 
         "w" : w, 
         "b" : b,
         "learning_rate" : learning_rate,
         "num_iterations": num_iterations}
    
    return d

if __name__ == "__main__":
    ## PUT YOUR IMAGE NAME) 
    my_image = root_path + "my_image2.jpg"   # change this to the name of your image file 
    # Loading the data hot-dog/not-hot-dog
    train_set_x, train_set_y, test_set_x, test_set_y = load_dataset_native()
    
    m_train = len(train_set_x)
    m_test = len(test_set_x)
    num_px = train_set_x.shape[1]
    
    print ("Number of training examples: m_train = " + str(m_train))
    print ("Number of testing examples: m_test = " + str(m_test))
    print ("Height/Width of each image: num_px = " + str(num_px))
    print ("Each image is of size: (" + str(num_px) + ", " + str(num_px) + ", 3)")
    print ("train_set_x shape: " + str(train_set_x.shape))
    print ("train_set_y shape: " + str(train_set_y.shape))
    print ("test_set_x shape: " + str(test_set_x.shape))
    print ("test_set_y shape: " + str(test_set_y.shape))
    
    
    print ("sigmoid([0, 2]) = " + str(sigmoid(np.array([0,2]))))
    dim = 2
    
    
    
    w, b = initialize_with_zeros(dim)
    print ("w = " + str(w))
    print ("b = " + str(b))
    
    w, b, X, Y = np.array([[1.],[2.]]), 2., np.array([[1.,2.,-1.],[3.,4.,-3.2]]), np.array([[1,0,1]])
    grads, cost = propagate(w, b, X, Y)
    print ("dw = " + str(grads["dw"]))
    print ("db = " + str(grads["db"]))
    print ("cost = " + str(cost))
    
    params, grads, costs = optimize(w, b, X, Y, num_iterations= 100, learning_rate = 0.009, print_cost = False)

    print ("w = " + str(params["w"]))
    print ("b = " + str(params["b"]))
    print ("dw = " + str(grads["dw"]))
    print ("db = " + str(grads["db"]))
    
    w = np.array([[0.1124579],[0.23106775]])
    b = -0.3
    X = np.array([[1.,-1.1,-3.2],[1.2,2.,0.1]])
    print ("predictions = " + str(predict(w, b, X)))
    
    print("Training the model")
    d = model(train_set_x, train_set_y, test_set_x, test_set_y, num_iterations = 2000, learning_rate = 0.002, print_cost = True)

    # Example of a picture that was wrongly classified.
    index = 1
    #plt.imshow(test_set_x[:,index].reshape((num_px, num_px, 3)))
    #print ("y = " + str(test_set_y[0,index]) + ", you predicted that it is a \"" + classes[d["Y_prediction_test"][0,index]].decode("utf-8") +  "\" picture.")
    
    
    # Plot learning curve (with costs)
    #costs = np.squeeze(d['costs'])
    #plt.plot(costs)
    #plt.ylabel('cost')
    #plt.xlabel('iterations (per hundreds)')
    #plt.title("Learning rate =" + str(d["learning_rate"]))
    #plt.show()
    
    learning_rates = [0.02, 0.01, 0.005]
    models = {}
    for i in learning_rates:
        print ("learning rate is: " + str(i))
        models[str(i)] = model(train_set_x, train_set_y, test_set_x, test_set_y, num_iterations = 1500, learning_rate = i, print_cost = False)
        print ('\n' + "-------------------------------------------------------" + '\n')
    
    for i in learning_rates:
        plt.plot(np.squeeze(models[str(i)]["costs"]), label= str(models[str(i)]["learning_rate"]))
    
    plt.ylabel('cost')
    plt.xlabel('iterations (hundreds)')
    
    legend = plt.legend(loc='upper center', shadow=True)
    frame = legend.get_frame()
    frame.set_facecolor('0.90')
    plt.show()
    
    
    
    # We preprocess the image to fit your algorithm.
    fname = "images/" + my_image
    image = np.array(imageio.imread(fname))
    my_image = Image.fromarray(image)
    my_image = my_image.resize(size=(dimention,dimention))
    my_image = np.reshape(my_image, (1, dimention*dimention*3)).T
    
    main_model = models[str(0.02)]
    my_predicted_image = predict(d["w"], d["b"], my_image)
    print("The given image is Hotdog: " + str(my_predicted_image))
    
    plt.imshow(image)
    #print("y = " + str(np.squeeze(my_predicted_image)) + ", your algorithm predicts a \"" + classes[int(np.squeeze(my_predicted_image)),].decode("utf-8") +  "\" picture.")
# Out:
# Streaming output truncated to the last 5000 lines.
# Image Size:  (384, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/564558.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/143012.jpg
# Image Size:  (384, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/287752.jpg
# Image Size:  (382, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/800992.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/604245.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/651101.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/219922.jpg
# Image Size:  (341, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/173995.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/456751.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/728442.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/259058.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/500771.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/268919.jpg
# Image Size:  (382, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/156126.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/480916.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/739229.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/289472.jpg
# Image Size:  (512, 382)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/424960.jpg
# Image Size:  (512, 383)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/393123.jpg
# Image Size:  (512, 382)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/156135.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/317564.jpg
# Image Size:  (512, 382)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/445366.jpg
# Image Size:  (512, 446)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/718939.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/397071.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/138969.jpg
# Image Size:  (384, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/138937.jpg
# Image Size:  (382, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/388827.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/745739.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/439441.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/826706.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/485835.jpg
# Image Size:  (512, 306)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/315220.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/829968.jpg
# Image Size:  (384, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/170452.jpg
# Image Size:  (382, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/316636.jpg
# Image Size:  (512, 382)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/498141.jpg
# Image Size:  (384, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/510955.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/458164.jpg
# Image Size:  (512, 307)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/752871.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/193755.jpg
# Image Size:  (382, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/224850.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/716049.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/533521.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/403561.jpg
# Image Size:  (382, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/345704.jpg
# Image Size:  (512, 382)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/307874.jpg
# Image Size:  (384, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/190809.jpg
# Image Size:  (512, 382)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/570799.jpg
# Image Size:  (512, 288)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/397696.jpg
# Image Size:  (382, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/544416.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/413825.jpg
# Image Size:  (384, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/691952.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/618167.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/388733.jpg
# Image Size:  (512, 382)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/550512.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/807265.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/152106.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/690320.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/839783.jpg
# Image Size:  (512, 341)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/551784.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/697073.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/652826.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/677481.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/349375.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/756061.jpg
# Image Size:  (382, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/566784.jpg
# Image Size:  (512, 383)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/209306.jpg
# Image Size:  (382, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/315747.jpg
# Image Size:  (512, 382)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/591179.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/704107.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/410713.jpg
# Image Size:  (382, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/423659.jpg
# Image Size:  (384, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/160274.jpg
# Image Size:  (382, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/198641.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/518867.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/583811.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/282294.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/703550.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/628106.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/211824.jpg
# Image Size:  (382, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/267988.jpg
# Image Size:  (384, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/704826.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/531567.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/380645.jpg
# Image Size:  (382, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/180961.jpg
# Image Size:  (512, 382)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/612440.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/608168.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/170212.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/306950.jpg
# Image Size:  (512, 382)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/189511.jpg
# Image Size:  (382, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/133245.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/818233.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/581166.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/146834.jpg
# Image Size:  (384, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/593867.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/336873.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/505584.jpg
# Image Size:  (512, 382)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/210861.jpg
# Image Size:  (512, 341)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/206995.jpg
# Image Size:  (384, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/377852.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/146227.jpg
# Image Size:  (384, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/207335.jpg
# Image Size:  (512, 382)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/292683.jpg
# Image Size:  (384, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/397466.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/640478.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/371082.jpg
# Image Size:  (382, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/370167.jpg
# Image Size:  (512, 382)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/197257.jpg
# Image Size:  (512, 382)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/422730.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/337987.jpg
# Image Size:  (512, 456)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/453463.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/135628.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/462004.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/307557.jpg
# Image Size:  (512, 306)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/398941.jpg
# Image Size:  (382, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/391898.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/171875.jpg
# Image Size:  (382, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/595636.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/607289.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/679424.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/139177.jpg
# Image Size:  (341, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/373912.jpg
# Image Size:  (384, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/332886.jpg
# Image Size:  (512, 500)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/731744.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/841980.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/588881.jpg
# Image Size:  (512, 442)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/233179.jpg
# Image Size:  (384, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/599728.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/210271.jpg
# Image Size:  (512, 288)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/533172.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/762910.jpg
# Image Size:  (512, 342)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/842474.jpg
# Image Size:  (512, 341)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/667655.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/195251.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/527074.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/537584.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/324480.jpg
# Image Size:  (384, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/493727.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/238581.jpg
# Image Size:  (382, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/250715.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/574379.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/815805.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/807481.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/171607.jpg
# Image Size:  (384, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/571081.jpg
# Image Size:  (511, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/289042.jpg
# Image Size:  (512, 341)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/784362.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/500768.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/561681.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/741652.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/580378.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/264487.jpg
# Image Size:  (382, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/142835.jpg
# Image Size:  (512, 382)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/554307.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/165005.jpg
# Image Size:  (382, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/724711.jpg
# Image Size:  (512, 343)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/623958.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/824342.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/701763.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/635715.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/528022.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/558890.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/707784.jpg
# Image Size:  (512, 385)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/319114.jpg
# Image Size:  (512, 382)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/324507.jpg
# Image Size:  (512, 341)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/225367.jpg
# Image Size:  (384, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/520065.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/343270.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/248122.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/201986.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/352638.jpg
# Image Size:  (512, 382)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/840832.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/200438.jpg
# Image Size:  (512, 342)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/327851.jpg
# Image Size:  (384, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/295307.jpg
# Image Size:  (512, 306)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/840839.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/745741.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/415744.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/408504.jpg
# Image Size:  (512, 388)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/646412.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/138933.jpg
# Image Size:  (382, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/259418.jpg
# Image Size:  (384, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/471340.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/665987.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/489624.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/510674.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/697329.jpg
# Image Size:  (512, 382)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/502977.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/413426.jpg
# Image Size:  (382, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/461937.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/285214.jpg
# Image Size:  (384, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/379311.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/632174.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/527633.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/267629.jpg
# Image Size:  (384, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/400228.jpg
# Image Size:  (382, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/409435.jpg
# Image Size:  (382, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/741637.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/298757.jpg
# Image Size:  (384, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/635712.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/838604.jpg
# Image Size:  (383, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/219273.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/486658.jpg
# Image Size:  (512, 307)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/803307.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/607287.jpg
# Image Size:  (384, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/602204.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/380963.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/382188.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/417155.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/505563.jpg
# Image Size:  (512, 382)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/642331.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/530316.jpg
# Image Size:  (306, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/212515.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/183400.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/300150.jpg
# Image Size:  (382, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/547307.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/315602.jpg
# Image Size:  (512, 306)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/365524.jpg
# Image Size:  (382, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/291354.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/207291.jpg
# Image Size:  (382, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/161911.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/520905.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/419255.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/805852.jpg
# Image Size:  (384, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/144956.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/576265.jpg
# Image Size:  (512, 490)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/690327.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/595968.jpg
# Image Size:  (512, 307)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/619671.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/133012.jpg
# Image Size:  (382, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/160523.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/634232.jpg
# Image Size:  (512, 306)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/514482.jpg
# Image Size:  (512, 500)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/573731.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/654831.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/302949.jpg
# Image Size:  (512, 406)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/335113.jpg
# Image Size:  (512, 268)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/566965.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/723890.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/154545.jpg
# Image Size:  (512, 382)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/650514.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/147874.jpg
# Image Size:  (384, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/154409.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/717652.jpg
# Image Size:  (382, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/hot_dog/701201.jpg
# Image Size:  (512, 289)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/not_hot_dog/15787.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/not_hot_dog/45817.jpg
# Image Size:  (512, 341)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/not_hot_dog/42487.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/not_hot_dog/23601.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/not_hot_dog/17394.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/not_hot_dog/26489.jpg
# Image Size:  (384, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/not_hot_dog/18985.jpg
# Image Size:  (384, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/not_hot_dog/40449.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/not_hot_dog/40231.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/not_hot_dog/47909.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/not_hot_dog/13023.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/not_hot_dog/44035.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/not_hot_dog/43924.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/not_hot_dog/22489.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/not_hot_dog/44810.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/not_hot_dog/42252.jpg
# Image Size:  (512, 346)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/not_hot_dog/48052.jpg
# Image Size:  (512, 341)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/not_hot_dog/44449.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/not_hot_dog/24479.jpg
# Image Size:  (384, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/not_hot_dog/32199.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/not_hot_dog/29417.jpg
# Image Size:  (384, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/not_hot_dog/47115.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/not_hot_dog/28783.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/not_hot_dog/32004.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/not_hot_dog/17688.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/not_hot_dog/17969.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/not_hot_dog/48506.jpg
# Image Size:  (512, 307)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/not_hot_dog/50277.jpg
# Image Size:  (384, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/not_hot_dog/29869.jpg
# Image Size:  (384, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/not_hot_dog/24844.jpg
# Image Size:  (512, 343)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/not_hot_dog/48151.jpg
# Image Size:  (384, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/not_hot_dog/27963.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/not_hot_dog/42954.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/not_hot_dog/53758.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/not_hot_dog/52510.jpg
# Image Size:  (384, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/not_hot_dog/17304.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/not_hot_dog/25414.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/not_hot_dog/22080.jpg
# Image Size:  (512, 342)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/not_hot_dog/20087.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/not_hot_dog/41693.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/not_hot_dog/46325.jpg
# Image Size:  (512, 307)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/not_hot_dog/43376.jpg
# Image Size:  (384, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/not_hot_dog/48840.jpg
# Image Size:  (384, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/not_hot_dog/24656.jpg
# Image Size:  (384, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/not_hot_dog/15580.jpg
# Image Size:  (512, 364)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/not_hot_dog/37384.jpg
# Image Size:  (384, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/not_hot_dog/45200.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/not_hot_dog/45896.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/not_hot_dog/35235.jpg
# Image Size:  (384, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/not_hot_dog/32693.jpg
# Image Size:  (384, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/test/not_hot_dog/26279.jpg
# Image Size:  (384, 512)
#
# Image Size:  (64, 64)
#
# ...
# Image Size:  (384, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/267713.jpg
# Image Size:  (384, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/296039.jpg
# Image Size:  (382, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/303460.jpg
# Image Size:  (512, 382)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/91432.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/238410.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/791662.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/835998.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/320734.jpg
# Image Size:  (512, 382)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/250720.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/291636.jpg
# Image Size:  (382, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/89502.jpg
# Image Size:  (384, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/90930.jpg
# Image Size:  (383, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/95565.jpg
# Image Size:  (384, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/234706.jpg
# Image Size:  (512, 382)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/90167.jpg
# Image Size:  (382, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/284999.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/90481.jpg
# Image Size:  (384, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/217445.jpg
# Image Size:  (512, 382)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/97656.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/290382.jpg
# Image Size:  (512, 382)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/4770.jpg
# Image Size:  (384, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/319830.jpg
# Image Size:  (382, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/769437.jpg
# Image Size:  (306, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/89974.jpg
# Image Size:  (383, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/6021.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/816725.jpg
# Image Size:  (512, 383)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/98607.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/92235.jpg
# Image Size:  (512, 343)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/768793.jpg
# Image Size:  (512, 382)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/823536.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/89197.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/303809.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/801827.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/309651.jpg
# Image Size:  (512, 382)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/223676.jpg
# Image Size:  (382, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/5764.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/239724.jpg
# Image Size:  (512, 382)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/246510.jpg
# Image Size:  (382, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/230015.jpg
# Image Size:  (512, 341)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/4176.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/311779.jpg
# Image Size:  (384, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/274711.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/765053.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/232844.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/265743.jpg
# Image Size:  (382, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/96357.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/816756.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/322067.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/748088.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/222586.jpg
# Image Size:  (382, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/244006.jpg
# Image Size:  (382, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/749374.jpg
# Image Size:  (289, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/96213.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/90989.jpg
# Image Size:  (451, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/94215.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/5813.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/815394.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/797686.jpg
# Image Size:  (512, 385)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/90116.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/6127.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/824157.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/92331.jpg
# Image Size:  (384, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/338101.jpg
# Image Size:  (384, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/296611.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/817533.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/93653.jpg
# Image Size:  (512, 383)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/95572.jpg
# Image Size:  (384, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/98675.jpg
# Image Size:  (382, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/223944.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/759160.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/331674.jpg
# Image Size:  (384, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/803895.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/4889.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/251128.jpg
# Image Size:  (384, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/796326.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/790763.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/93961.jpg
# Image Size:  (384, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/302329.jpg
# Image Size:  (512, 340)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/225804.jpg
# Image Size:  (512, 382)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/258877.jpg
# Image Size:  (382, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/266364.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/781137.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/236973.jpg
# Image Size:  (382, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/96524.jpg
# Image Size:  (383, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/90923.jpg
# Image Size:  (512, 383)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/292607.jpg
# Image Size:  (512, 341)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/766638.jpg
# Image Size:  (512, 384)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/293052.jpg
# Image Size:  (512, 378)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/256347.jpg
# Image Size:  (512, 382)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/99890.jpg
# Image Size:  (384, 512)
#
# Image Size:  (64, 64)
#
# Preprocessing Image:  /content/gdrive/My Drive/machineLearning/hotDogClassifier/datasets/train/not_hot_dog/822411.jpg
# Image Size:  (512, 512)
#
# Image Size:  (64, 64)
# Flattening the images to [64*64*3 x 1] dimentions
# arr shape: (12288, 250)
# arr shape: (12288, 250)
# arr shape: (12288, 249)
# arr shape: (12288, 249)
# Merging, mixing data
# Merging, mixing data
# Number of training examples: m_train = 12288
# Number of testing examples: m_test = 12288
# Height/Width of each image: num_px = 498
# Each image is of size: (498, 498, 3)
# train_set_x shape: (12288, 498)
# train_set_y shape: (498,)
# test_set_x shape: (12288, 500)
# test_set_y shape: (500,)
# sigmoid([0, 2]) = [0.5        0.88079708]
# w = [[0.]
#  [0.]]
# b = 0
# dw = [[0.99845601]
#  [2.39507239]]
# db = 0.001455578136784208
# cost = 5.801545319394553
# w = [[0.19033591]
#  [0.12259159]]
# b = 1.9253598300845747
# dw = [[0.67752042]
#  [1.41625495]]
# db = 0.21919450454067657
# predictions = [[1. 1. 0.]]
# Training the model
